# %%
# !pip install pymongo[srv]

# %%
import pymongo
import numpy as np 
from pymongo import MongoClient

# %%
client = pymongo.MongoClient("mongodb+srv://admin:cldmv808@cluster0.nvycu.gcp.mongodb.net/test")

# %%
client.list_database_names()
# Out:
# ['anatel',
#  'estudo',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'test',
#  'admin',
#  'local']

# %%
db = client.anatel

# %%
db.minas.count_documents({})
# Out:
# 509706

# %%
list(db.minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb2c364dfd1d92094d6ecc7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 3},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6ecc8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 8},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6ecc9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
list(db.list_collections())
# Out:
# [{'name': 'minas',
#   'type': 'collection',
#   'options': {},
#   'info': {'readOnly': False,
#    'uuid': UUID('1351dd31-143b-4b5a-b35e-68b257fef9f5')},
#   'idIndex': {'v': 2,
#    'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'anatel.minas'}}]

# %%
max = db.minas.aggregate([{ "$group": { "_id": {}, "max": { "$max": "$QtdeSolic" }}}])
valor = np.array(list(max))
max = valor[0]['max']

result = db.minas.aggregate([{ "$match": { "QtdeSolic": { "$eq": max }}}])

list(result)
# Out:
# [{'_id': ObjectId('5fb2c41fdfd1d92094d90ccd'),
#   'DataExtracao': datetime.datetime(2016, 4, 19, 0, 0),
#   'Ano': 2013,
#   'Mes': 12,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 4164}]

# %%
result = db.minas.aggregate([{ "$group": { "_id": {}, "min": { "$min": "$QtdeSolic" }}}])
valor = np.array(list(result))
valor_minimo = valor[0]['min']
print(valor_minimo)
# Out:
# 1

# %%
result = db.minas.aggregate([{ "$match": { "QtdeSolic": { "$eq": valor_minimo }}}])

list(result)
# Out:
# [{'_id': ObjectId('5fb2c364dfd1d92094d6ecc9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6ecca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6eccb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
count_servicos= db.minas.aggregate([{ "$group": { "_id": "$Servico", "Total": { "$sum": 1 }}}]);
list(count_servicos)
# Out:
# [{'_id': 'TV por Assinatura', 'Total': 80646},
#  {'_id': 'Radioamador (PY)', 'Total': 1350},
#  {'_id': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Total': 531},
#  {'_id': 'Serviços da Anatel', 'Total': 10017},
#  {'_id': 'Serviço de Comunicação Multimídia', 'Total': 23210},
#  {'_id': 'Telefone Fixo', 'Total': 63200},
#  {'_id': 'Móvel Pessoal', 'Total': 68399},
#  {'_id': 'Banda Larga Fixa', 'Total': 60722},
#  {'_id': 'Serviço Telefônico Fixo Comutado - STFC', 'Total': 41299},
#  {'_id': 'Limitado Privado', 'Total': 646},
#  {'_id': 'Serviço Móvel Aeronáutico', 'Total': 105},
#  {'_id': 'Radiochamada (Paging)', 'Total': 24},
#  {'_id': 'Outros', 'Total': 969},
#  {'_id': 'Celular Pré-Pago', 'Total': 56911},
#  {'_id': 'Radiodifusão (Rádio e TV)', 'Total': 3476},
#  {'_id': 'Serviço Móvel Marítimo', 'Total': 20},
#  {'_id': 'Rádio do Cidadão (PX)', 'Total': 1240},
#  {'_id': 'Troncalizado (Trunking)', 'Total': 586},
# ...

# %%
result = db.minas.aggregate([{"$match":{"Tipo":{"$eq": "Reclamação"}}}])

list(result)
# Out:
# [{'_id': ObjectId('5fb2c364dfd1d92094d6ecc9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6ecca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb2c364dfd1d92094d6eccb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
# ...

# %%
tipo_valores = db.minas.distinct("Tipo")
list(tipo_valores)
# Out:
# ['Denúncia', 'Elogio', 'Pedido de Informação', 'Reclamação', 'Sugestão']
